# %%
import numpy as np
import pandas as pd
from scipy.io import arff

# %%
data=arff.loadarff(r'C:\Users\dhineshkumar.s\Downloads\speeddating.arff')
v=pd.DataFrame(data[0])
for column,datatype in v.dtypes.items():
    if datatype == np.object:
        v[column]=v[column].str.decode('utf-8').fillna(v[column])
v=v.replace('male',0)
v=v.replace('female',1)
display(v)
# Out:
#      has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0           0   1.0       1  21.0   27.0    6.0   [4-6]
# 1           0   1.0       1  21.0   22.0    1.0   [0-1]
# 2           1   1.0       1  21.0   22.0    1.0   [0-1]
# 3           0   1.0       1  21.0   23.0    2.0   [2-3]
# 4           0   1.0       1  21.0   24.0    3.0   [2-3]
# ...       ...   ...     ...   ...    ...    ...     ...
# 8373        1  21.0       0  25.0   26.0    1.0   [0-1]
# 8374        1  21.0       0  25.0   24.0    1.0   [0-1]
# 8375        1  21.0       0  25.0   29.0    4.0   [4-6]
# 8376        1  21.0       0  25.0   22.0    3.0   [2-3]
# 8377        1  21.0       0  25.0   22.0    3.0   [2-3]
#
#                                        race  \
# 0     Asian/Pacific Islander/Asian-American
# 1     Asian/Pacific Islander/Asian-American
# 2     Asian/Pacific Islander/Asian-American
# 3     Asian/Pacific Islander/Asian-American
# 4     Asian/Pacific Islander/Asian-American
# ...

# %%
v['age'].mean()
# Out:
# 26.358927924664975

# %%
print(v.dtypes)
# Out:
# has_null               object
# wave                  float64
# gender                  int64
# age                   float64
# age_o                 float64
#                        ...
# d_guess_prob_liked     object
# met                   float64
# decision               object
# decision_o             object
# match                  object
# Length: 123, dtype: object

# %%
v_max_scaled=v.copy()
column='age_o'
v_max_scaled[column]=v_max_scaled[column]/v_max_scaled[column].abs().max()
display(v_max_scaled)
# Out:
#      has_null  wave  gender   age     age_o  d_age d_d_age  \
# 0           0   1.0       1  21.0  0.490909    6.0   [4-6]
# 1           0   1.0       1  21.0  0.400000    1.0   [0-1]
# 2           1   1.0       1  21.0  0.400000    1.0   [0-1]
# 3           0   1.0       1  21.0  0.418182    2.0   [2-3]
# 4           0   1.0       1  21.0  0.436364    3.0   [2-3]
# ...       ...   ...     ...   ...       ...    ...     ...
# 8373        1  21.0       0  25.0  0.472727    1.0   [0-1]
# 8374        1  21.0       0  25.0  0.436364    1.0   [0-1]
# 8375        1  21.0       0  25.0  0.527273    4.0   [4-6]
# 8376        1  21.0       0  25.0  0.400000    3.0   [2-3]
# 8377        1  21.0       0  25.0  0.400000    3.0   [2-3]
#
#                                        race  \
# 0     Asian/Pacific Islander/Asian-American
# 1     Asian/Pacific Islander/Asian-American
# 2     Asian/Pacific Islander/Asian-American
# 3     Asian/Pacific Islander/Asian-American
# ...

# %%
v=v.replace('?',np.nan)
v
# Out:
#      has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0         NaN   1.0       1  21.0   27.0    6.0   [4-6]
# 1         NaN   1.0       1  21.0   22.0    1.0   [0-1]
# 2           1   1.0       1  21.0   22.0    1.0   [0-1]
# 3         NaN   1.0       1  21.0   23.0    2.0   [2-3]
# 4         NaN   1.0       1  21.0   24.0    3.0   [2-3]
# ...       ...   ...     ...   ...    ...    ...     ...
# 8373        1  21.0       0  25.0   26.0    1.0   [0-1]
# 8374        1  21.0       0  25.0   24.0    1.0   [0-1]
# 8375        1  21.0       0  25.0   29.0    4.0   [4-6]
# 8376        1  21.0       0  25.0   22.0    3.0   [2-3]
# 8377        1  21.0       0  25.0   22.0    3.0   [2-3]
#
#                                        race  \
# 0     Asian/Pacific Islander/Asian-American
# 1     Asian/Pacific Islander/Asian-American
# 2     Asian/Pacific Islander/Asian-American
# 3     Asian/Pacific Islander/Asian-American
# 4     Asian/Pacific Islander/Asian-American
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x=v.iloc[:,5]
y=v.iloc[:,6]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
x_test=x_test.values.reshape(-1,1)
x_train=x_train.values.reshape(-1,1)

# %%
x_train
# Out:
# array([[ 9.],
#        [ 2.],
#        [10.],
#        ...,
#        [ 2.],
#        [ 6.],
#        [ 1.]])

# %%
y_train
# Out:
# 3545    [7-37]
# 3132     [2-3]
# 5432    [7-37]
# 6184     [4-6]
# 1949     [2-3]
#          ...
# 4373    [7-37]
# 7891    [7-37]
# 4859     [2-3]
# 3264     [4-6]
# 2732     [0-1]
# Name: d_d_age, Length: 5585, dtype: object

# %%
x_test
# Out:
# array([[3.],
#        [5.],
#        [0.],
#        ...,
#        [0.],
#        [2.],
#        [1.]])

# %%
y_test
# Out:
# 2265    [2-3]
# 2851    [4-6]
# 3655    [0-1]
# 196     [2-3]
# 3719    [4-6]
#         ...
# 2696    [4-6]
# 2126    [2-3]
# 282     [0-1]
# 6512    [2-3]
# 2448    [0-1]
# Name: d_d_age, Length: 2793, dtype: object

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
lin_reg=linear_model.LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-71d391392b97> in <module>
#       4 import matplotlib.pyplot as plt
#       5 lin_reg=linear_model.LinearRegression()
# ----> 6 lin_reg.fit(x_train,y_train)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
import matplotlib.pyplot as plt
v.plot(x="age",y="age_o")

# %%
v.plot.hist(bins=11,alpha=1)

# %%
v.plot.line()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d0aa4386ac53> in <module>
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
import numpy as np
import pandas as pd
from scipy.io import arff

# %%
data=arff.loadarff(r'C:\Users\dhineshkumar.s\Downloads\speeddating.arff')
v=pd.DataFrame(data[0])
for column,datatype in v.dtypes.items():
    if datatype == np.object:
        v[column]=v[column].str.decode('utf-8').fillna(v[column])
v=v.replace('male',0)
v=v.replace('female',1)
display(v)
# Out:
#      has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0           0   1.0       1  21.0   27.0    6.0   [4-6]
# 1           0   1.0       1  21.0   22.0    1.0   [0-1]
# 2           1   1.0       1  21.0   22.0    1.0   [0-1]
# 3           0   1.0       1  21.0   23.0    2.0   [2-3]
# 4           0   1.0       1  21.0   24.0    3.0   [2-3]
# ...       ...   ...     ...   ...    ...    ...     ...
# 8373        1  21.0       0  25.0   26.0    1.0   [0-1]
# 8374        1  21.0       0  25.0   24.0    1.0   [0-1]
# 8375        1  21.0       0  25.0   29.0    4.0   [4-6]
# 8376        1  21.0       0  25.0   22.0    3.0   [2-3]
# 8377        1  21.0       0  25.0   22.0    3.0   [2-3]
#
#                                        race  \
# 0     Asian/Pacific Islander/Asian-American
# 1     Asian/Pacific Islander/Asian-American
# 2     Asian/Pacific Islander/Asian-American
# 3     Asian/Pacific Islander/Asian-American
# 4     Asian/Pacific Islander/Asian-American
# ...

# %%
v.head().plot.pie(x='wave',y='d_age')
